# %% [markdown]
# ## Scraping AirBnb  Web

# %% [markdown]
# ### Import Libraries

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import requests
import re
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
# from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.by import By
import time
import random as ran
import numpy as np

# %% [markdown]
# ### Scraping

# %%
def download_html(url):
    url = quote(url, safe=':/?&=')
    with urllib.request.urlopen(url) as response:
        html = response.read()
        html = html.decode('utf-8')
    response.close()
    return html

# %%
def get_driver(url, waiting_time = 20):
    options = Options()
    options.add_argument('--no-sandbox')
    options.add_argument('--headless=new')
    options.add_argument('--disable-dev-shm-usage')        
    options.add_argument('--blink-settings=imagesEnabled=false')
    driver = webdriver.Chrome(options=options)

    # options = Options()
    # options.headless = True  # Chế độ headless (không có giao diện người dùng)
    # # options.set_preference('permissions.default.image', 2)  # Tắt hình ảnh

    # driver = webdriver.Firefox(options=options)

    for i in range(10):
        try:
            driver.get(url)
            break
        except:
            pass
    time.sleep(waiting_time)
    return driver

# %%
def download_dynamic_html(url):
        for i in range(10):
                try:
                        driver = get_driver(url,20)
                        break
                except:
                        pass

        pageSource = driver.page_source
        driver.quit()
        return pageSource

# %%
def move_page(url,page):
    html = download_dynamic_html(url)
    soup = BeautifulSoup(html, 'html.parser')

    elements = soup.find_all('a',{'class':'l1ovpqvx atm_1y33qqm_1ggndnn_10saat9 atm_17zvjtw_zk357r_10saat9 atm_w3cb4q_il40rs_10saat9 c1ackr0h atm_c8_fkimz8 atm_g3_11yl58k atm_fr_4ym3tx atm_cs_qo5vgd atm_9s_1txwivl atm_h_1h6ojuz atm_fc_1h6ojuz atm_bb_idpfg4 atm_3f_glywfm atm_5j_1ssbidh atm_26_1j28jx2 atm_7l_18pqv07 atm_vy_1vi7ecw atm_e2_1vi7ecw atm_gi_idpfg4 atm_gz_logulu atm_h0_logulu atm_l8_idpfg4 atm_uc_1dtz4sb atm_kd_glywfm atm_uc_glywfm__p88qr9 atm_26_1nh1gcj_1nos8r_uv4tnr atm_tr_kv3y6q_csw3t1 atm_26_1nh1gcj_csw3t1 atm_9j_73adwj_1o5j5ji atm_3f_glywfm_jo46a5 atm_l8_idpfg4_jo46a5 atm_gi_idpfg4_jo46a5 atm_3f_glywfm_1icshfk atm_kd_glywfm_19774hq atm_uc_x37zl0_1w3cfyq atm_26_1nh1gcj_1w3cfyq atm_70_1o9v3ru_1w3cfyq atm_uc_glywfm_1w3cfyq_p88qr9 atm_uc_x37zl0_18zk5v0 atm_26_1nh1gcj_18zk5v0 atm_70_1o9v3ru_18zk5v0 atm_uc_glywfm_18zk5v0_p88qr9 dir dir-ltr'})
    for element in elements:
        if element.get_text() == str(page):
            print('\r' + "Found page url: ", page,flush = True, end = "")
            link = 'https://www.airbnb.com.vn' + element.get('href')
            return link
    print('\r' + "Not found page: ", page,flush = True, end = "")
    return None

# %%
def get_all_page(url):
    pages = []
    pages.append(url)
    pre_page = url
    for i in range(2,16):
        cur_page = move_page(pre_page, i)
        if cur_page:
            pre_page = cur_page
            pages.append(cur_page)
        else:
            break
        time.sleep(2)
        
    return pages

# %%
def extract_page(url):
    source = download_html(url)
    soup = BeautifulSoup(source,'lxml')
    houses = soup.find_all('meta',{'itemprop':'url'})
    links = []
    for link in houses:
        URL = 'https://' + link.get('content')
        links.append(URL)
    return links

# %%
def get_all_house(url):
    lists = []
    pages = get_all_page(url)
    for page in pages:
        houses = extract_page(page)
        lists.extend(houses)
    return lists

# %%
def get_source(url):
    driver = get_driver(url,40)
    for i in range(10):
        try:
            button = driver.find_element(By.XPATH,"//button[@class = 'l1ovpqvx atm_1y33qqm_1ggndnn_10saat9 atm_17zvjtw_zk357r_10saat9 atm_w3cb4q_il40rs_10saat9 b65jmrv atm_9j_tlke0l atm_9s_1o8liyq atm_gi_idpfg4 atm_mk_h2mmj6 atm_r3_1h6ojuz atm_rd_glywfm atm_3f_97hwo atm_vy_1wugsn5 atm_tl_1gw4zv3 atm_9j_13gfvf7_1o5j5ji v7aged4 atm_bx_1ltc5j7 atm_c8_8ycq01 atm_g3_adnk3f atm_cs_qo5vgd atm_5j_9l7fl4 atm_6h_t94yts atm_66_nqa18y atm_uc_1c5iv21 atm_kd_glywfm atm_4b_18pqv07 atm_26_1hbpp16 atm_7l_18pqv07 atm_l8_1vkzbvs atm_uc_glywfm__p88qr9 atm_3f_glywfm_jo46a5 atm_l8_idpfg4_jo46a5 atm_gi_idpfg4_jo46a5 atm_3f_glywfm_1icshfk atm_kd_glywfm_19774hq atm_uc_x37zl0_1w3cfyq atm_uc_glywfm_1w3cfyq_p88qr9 atm_uc_x37zl0_18zk5v0 atm_uc_glywfm_18zk5v0_p88qr9 atm_tr_18md41p_csw3t1 atm_k4_kb7nvz_1o5j5ji atm_4b_18pqv07_1w3cfyq atm_7l_18pqv07_1w3cfyq atm_70_216vci_1w3cfyq atm_4b_18pqv07_18zk5v0 atm_7l_18pqv07_18zk5v0 atm_70_216vci_18zk5v0 atm_4b_1otlplk_1nos8r atm_26_1nh1gcj_1nos8r atm_7l_18pqv07_1nos8r atm_4b_1otlplk_csw3t1 atm_26_1nh1gcj_csw3t1 atm_7l_18pqv07_csw3t1 atm_4b_161hw1_1o5j5ji atm_26_1hbpp16_1o5j5ji atm_7l_161hw1_1o5j5ji dir dir-ltr']")
            driver.execute_script("arguments[0].click();", button)
            break
        except:
            pass
        
    time.sleep(10)
    pageSource = driver.page_source

    driver.quit()

    return pageSource

# %%
def extract_amenities(soup):
    amenities = soup.find_all('div', {'class': '_11jhslp'})
    
    amenities_dict = {}
    for amenity in amenities:
        header = amenity.find('h3', {'class': 'hpipapi atm_7l_1kw7nm4 atm_c8_1x4eueo atm_cs_1kw7nm4 atm_g3_1kw7nm4 atm_gi_idpfg4 atm_l8_idpfg4 atm_kd_idpfg4_pfnrn2 dir dir-ltr'}).get_text()
        values = amenity.find_all('div', {'class': 'f16mr5nx atm_9s_1txwivl dir dir-ltr'})
        values = [v.find(string=True) for v in values]
        
        amenities_dict['amenity_' + header] = values
    return amenities_dict

# %%
def extract_ratings(soup):
    total = soup.find('span',{'class':'t1rl3yjt atm_9s_116y0ak dir dir-ltr'})
    ratings = soup.find_all('div',{'class':'l925rvg atm_9s_1txwivl atm_ar_1bp4okc atm_cx_yh40bf dir dir-ltr'})
    ratings_dict = {}
    ratings_dict['rating_Total'] = total.find('div',{'dir':'ltr'}).get_text()
    for rating in ratings:
        header = rating.contents[0].get_text()
        values = rating.contents[1].get_text()
        
        ratings_dict['rating_' + header] = values
    return ratings_dict

# %%
def extract_prices(soup):
    try:
        price_per_night = soup.find('span',{'class':'_tyxjp1'}).get_text().replace('\xa0', '')
    except:
        price_per_night = soup.find('span',{'class':'_1y74zjx'}).get_text().replace('\xa0', '')

    
    prices = soup.find_all('div',{'class':'_tr4owt'})
    prices = prices[1:]
    prices_dict = {}
    prices_dict['price_per_night'] = price_per_night
    for price in prices:
        header = price.find('div',{'class':'_m6lwl6'}).get_text()
        try:
            values = price.find('span',{'class':'_1k4xcdh'}).get_text()
        except:
            values = price.find('span',{'class':'_1rc8xn5'}).get_text()

        prices_dict['prices_' + header] = values
    return prices_dict

# %%
import json 

def scrape_house(url):
    source = get_source(url)
    soup = BeautifulSoup(source, 'html.parser')
    air_bnb_data = {}

    try:
        air_bnb_data['url'] = url
    except:
        air_bnb_data['url'] = None
        
    try:
        air_bnb_data['title'] = soup.find('span',{'class':'_1xxgv6l'}).get_text()
    except:
        air_bnb_data['title'] = None
    
    try:
        air_bnb_data['bed'] = soup.find('ol',{'class':'lgx66tx atm_gi_idpfg4 atm_l8_idpfg4 dir dir-ltr'}).get_text()
    except:
        air_bnb_data['bed'] = None
    try:
        air_bnb_data['title2'] = soup.find('div',{'class':'toieuka atm_c8_8ycq01 atm_g3_adnk3f atm_fr_rvubnj atm_cs_qo5vgd atm_c8_8nb4eg__oggzyc atm_g3_1dpnnv7__oggzyc atm_fr_11dsdeo__oggzyc dir dir-ltr'}).get_text()
    except:
        air_bnb_data['title2'] = None
    try:
        location = soup.find('div',{'class':'_leqb4t'})
        if location:
            air_bnb_data['location'] = location.get_text()
        else:
            air_bnb_data['location'] = soup.find('div',{'class':'_152qbzi'}).get_text()
    except:
        air_bnb_data['location'] = None
    
    try:
        air_bnb_data['badge'] = soup.find('div',{'class':'lbjrbi0 atm_le_1y44olf atm_lk_1y44olf atm_ll_1y44olf dir dir-ltr'}).get_text()
    except:
        air_bnb_data['badge'] = None        
    try:
        air_bnb_data['cancellation_policy'] = soup.find('div',{'class':'tutyap8 atm_gq_xvenqj dir dir-ltr'}).get_text()
    except:
        air_bnb_data['cancellation_policy'] = None   
    try:
        rules = soup.find_all('div', {'class': 'i1303y2k atm_h_1q9ycp6 atm_9s_1txwivl atm_gq_logulu dir dir-ltr'})
        pattern = re.compile('.*khách.*')

        for rule in rules:
            string = rule.get_text()  
            if re.search(pattern, string):  
                accommodates = string
                break 
        air_bnb_data['accommodates'] = accommodates
    except:
        air_bnb_data['accommodates'] = None   
    try:
        amenities = extract_amenities(soup)
        air_bnb_data.update(amenities)
    except:
        pass

    try:
        ratings = extract_ratings(soup)
        air_bnb_data.update(ratings)
    except:
        pass
    try:
        prices = extract_prices(soup)
        air_bnb_data.update(prices)
    except:
        pass
    return json.dumps(air_bnb_data)

# %%
def scrape_all_house(urls):
    house_list = []
    for house in urls:
        time.sleep(1)
        try:
            house_data = scrape_house(house)
        except:
            pass
        house_list.append(house_data)
    return house_list

# %%
# CPU intensive process -> use multiprocessing :)
from multiprocessing import Pool

# %%
# typically we could set "n" to the number of cpu's
import os
n_cpu = os.cpu_count()

# %%
# urls = ['https://www.airbnb.com.vn/s/B%C3%ACnh-Th%E1%BA%A1nh--Ho-Chi-Minh-City--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=B%C3%ACnh%20Th%E1%BA%A1nh%2C%20Ho%20Chi%20Minh%20City&place_id=ChIJ6eqoAp8odTER481V4JCd7DQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_clickextract_page(url)',
#        'https://www.airbnb.com.vn/s/Th%E1%BB%A7-%C4%90%E1%BB%A9c--Ho-Chi-Minh--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Th%E1%BB%A7%20%C4%90%E1%BB%A9c%2C%20Ho%20Chi%20Minh&place_id=ChIJS_ArBF7YdDERTTlkFuy6Jrs&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
#        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-7--Ho-Chi-Minh--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%207%2C%20Ho%20Chi%20Minh&place_id=ChIJk7BQsGAldTERycxVEMWJy20&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
#        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-1--Ho-Chi-Minh--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%201%2C%20Ho%20Chi%20Minh&place_id=ChIJe4jt-TgvdTERiYl2A1ftrRQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
#        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-5/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&date_picker_type=calendar&source=structured_search_input_header&search_type=filter_change']

# %%
# Quận Hoàn Kiếm, Hà Nội
# Quận Tây Hồ, Hà Nội
# Quận Ba Đình, Hà Nội
# Quận Hai Bà Trưng, Hà Nội
# Quận 1, Thành phố Hồ Chí Minh
# Quận 3, Thành phố Hồ Chí Minh
# Quận 5, Thành phố Hồ Chí Minh
# Quận 7, Thành phố Hồ Chí Minh
# Quận 10, Thành phố Hồ Chí Minh
# Quận 2, Thành phố Hồ Chí Minh
# Quận 9, Thành phố Hồ Chí Minh
# Quận Thủ Đức, Thành phố Hồ Chí Minh
# Quận Bình Thạnh, Thành phố Hồ Chí Minh
# Quận Phú Nhuận, Thành phố Hồ Chí Minh
# Quận Hải Châu, Thành phố Đà Nẵng
# Quận Sơn Trà, Thành phố Đà Nẵng
# Quận Ngũ Hành Sơn, Thành phố Đà Nẵng
# Tân phú
# Tân Bình
# đống đa
# cầu giấy
# long biên

# %%
urls = ['https://www.airbnb.com.vn/s/qu%E1%BA%ADn-Ho%C3%A0n-Ki%E1%BA%BFm--H%C3%A0-N%E1%BB%99i--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20Ho%C3%A0n%20Ki%E1%BA%BFm%2C%20H%C3%A0%20N%E1%BB%99i&place_id=ChIJKfTYWb-rNTERoWbl1t-jMHg&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-T%C3%A2y-H%E1%BB%93--H%C3%A0-N%E1%BB%99i--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20T%C3%A2y%20H%E1%BB%93%2C%20H%C3%A0%20N%E1%BB%99i&place_id=ChIJ1eJTQOWqNTERSyMixNexci0&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-Ba-%C4%90%C3%ACnh--H%C3%A0-N%E1%BB%99i--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20Ba%20%C4%90%C3%ACnh%2C%20H%C3%A0%20N%E1%BB%99i&place_id=ChIJBw_9cAmrNTERTu80ihJpRlw&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-Hai-B%C3%A0-Tr%C6%B0ng--H%C3%A0-N%E1%BB%99i--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20Hai%20B%C3%A0%20Tr%C6%B0ng%2C%20H%C3%A0%20N%E1%BB%99i&place_id=ChIJoXVwsR6sNTERScUSJVkX97E&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-1--Ho-Chi-Minh--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%201%2C%20Ho%20Chi%20Minh&place_id=ChIJe4jt-TgvdTERiYl2A1ftrRQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-3--Ho-Chi-Minh--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%203%2C%20Ho%20Chi%20Minh&place_id=ChIJJZQWJdYudTERtWNeFmhQXXc&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-5--Ho-Chi-Minh--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%205%2C%20Ho%20Chi%20Minh&place_id=ChIJh0sYffsudTERt_7_Mx0suQo&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-7--Th%C3%A0nh-ph%E1%BB%91-H%E1%BB%93-Ch%C3%AD-Minh--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%207%2C%20Th%C3%A0nh%20ph%E1%BB%91%20H%E1%BB%93%20Ch%C3%AD%20Minh&place_id=ChIJk7BQsGAldTERycxVEMWJy20&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-10--Th%C3%A0nh-ph%E1%BB%91-H%E1%BB%93-Ch%C3%AD-Minh--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%2010%2C%20Th%C3%A0nh%20ph%E1%BB%91%20H%E1%BB%93%20Ch%C3%AD%20Minh&place_id=ChIJZf3Ze9wudTERBA2mw2w5AHU&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-2--Th%E1%BB%A7-%C4%90%E1%BB%A9c--Th%C3%A0nh-ph%E1%BB%91-H%E1%BB%93-Ch%C3%AD-Minh--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%202%2C%20Th%E1%BB%A7%20%C4%90%E1%BB%A9c%2C%20Th%C3%A0nh%20ph%E1%BB%91%20H%E1%BB%93%20Ch%C3%AD%20Minh&place_id=ChIJS2kJGAQmdTEROTAQ8_pD1k8&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-9--Ho-Chi-Minh--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%209%2C%20Ho%20Chi%20Minh&place_id=ChIJdc5pOlsndTERry7BjxZjcPw&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-Th%E1%BB%A7-%C4%90%E1%BB%A9c--Th%C3%A0nh-ph%E1%BB%91-H%E1%BB%93-Ch%C3%AD-Minh--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20Th%E1%BB%A7%20%C4%90%E1%BB%A9c%2C%20Th%C3%A0nh%20ph%E1%BB%91%20H%E1%BB%93%20Ch%C3%AD%20Minh&place_id=ChIJS_ArBF7YdDERTTlkFuy6Jrs&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',   
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-B%C3%ACnh-Th%E1%BA%A1nh--Ho-Chi-Minh--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20B%C3%ACnh%20Th%E1%BA%A1nh%2C%20Ho%20Chi%20Minh&place_id=ChIJ6eqoAp8odTER481V4JCd7DQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-Ph%C3%BA-Nhu%E1%BA%ADn--Th%C3%A0nh-ph%E1%BB%91-H%E1%BB%93-Ch%C3%AD-Minh--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20Ph%C3%BA%20Nhu%E1%BA%ADn%2C%20Th%C3%A0nh%20ph%E1%BB%91%20H%E1%BB%93%20Ch%C3%AD%20Minh&place_id=ChIJNzThQN4odTERIW5CL5Juguo&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-H%E1%BA%A3i-Ch%C3%A2u--H%E1%BA%A3i-Ch%C3%A2u--%C4%90%C3%A0-N%E1%BA%B5ng--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20H%E1%BA%A3i%20Ch%C3%A2u%2C%20H%E1%BA%A3i%20Ch%C3%A2u%2C%20%C4%90%C3%A0%20N%E1%BA%B5ng&place_id=ChIJxb5s9rYZQjER3pLhr7FXD7w&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Qu%E1%BA%ADn-S%C6%A1n-Tr%C3%A0--%C4%90%C3%A0-N%E1%BA%B5ng--V%C3%B5-Nguy%C3%AAn-Gi%C3%A1p--M%C3%A2n-Th%C3%A1i--S%C6%A1n-Tr%C3%A0--%C4%90%C3%A0-N%E1%BA%B5ng--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Qu%E1%BA%ADn%20S%C6%A1n%20Tr%C3%A0%2C%20%C4%90%C3%A0%20N%E1%BA%B5ng%2C%20S%C6%A1n%20Tr%C3%A0%2C%20%C4%90%C3%A0%20N%E1%BA%B5ng&place_id=ChIJz78Ls40XQjERUExkfWHrFRY&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-Ng%C5%A9-H%C3%A0nh-S%C6%A1n--th%C3%A0nh-ph%E1%BB%91-%C4%90%C3%A0-N%E1%BA%B5ng--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20Ng%C5%A9%20H%C3%A0nh%20S%C6%A1n%2C%20th%C3%A0nh%20ph%E1%BB%91%20%C4%90%C3%A0%20N%E1%BA%B5ng&place_id=ChIJwxoXj0wXQjERoB86j7A0FV0&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-T%C3%A2n-Ph%C3%BA--Th%C3%A0nh-ph%E1%BB%91-H%E1%BB%93-Ch%C3%AD-Minh--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20T%C3%A2n%20Ph%C3%BA%2C%20Th%C3%A0nh%20ph%E1%BB%91%20H%E1%BB%93%20Ch%C3%AD%20Minh&place_id=ChIJdZHmM_crdTER_iUzc1M01tg&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/qu%E1%BA%ADn-T%C3%A2n-B%C3%ACnh--Th%C3%A0nh-ph%E1%BB%91-H%E1%BB%93-Ch%C3%AD-Minh--Vi%E1%BB%87t-Nam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=qu%E1%BA%ADn%20T%C3%A2n%20B%C3%ACnh%2C%20Th%C3%A0nh%20ph%E1%BB%91%20H%E1%BB%93%20Ch%C3%AD%20Minh&place_id=ChIJczqvGDgpdTERi8wKGNEWjc0&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/%C4%90%E1%BB%91ng-%C4%90a--Hanoi--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=%C4%90%E1%BB%91ng%20%C4%90a%2C%20Hanoi&place_id=ChIJ6-mLF4KrNTERdb1Jrv4EkUI&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/C%E1%BA%A7u-Gi%E1%BA%A5y--Hanoi--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=C%E1%BA%A7u%20Gi%E1%BA%A5y%2C%20Hanoi&place_id=ChIJMxD5VlerNTER_UtnLUQXaVc&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click',
        'https://www.airbnb.com.vn/s/Long-Bi%C3%AAn--Hanoi--Vietnam/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&monthly_start_date=2024-01-01&monthly_length=3&price_filter_input_type=0&channel=EXPLORE&query=Long%20Bi%C3%AAn%2C%20Hanoi&place_id=ChIJH8VyLm6pNTEReO7uDqaeaFQ&date_picker_type=calendar&source=structured_search_input_header&search_type=autocomplete_click'
        ]

# %%
# t0 = time.time()
# detail_features = scrape_house([0])
# print(time.time() - t0)

# %%
def scrape_all(url):
    listing_urls = get_all_house(url)
    for n_pools in [8]:
        with Pool(n_pools) as pool:
            result = list(pool.map(scrape_house, listing_urls))

        pool.close()
        pool.join()
    return [json.loads(house) for house in result]

# %%
# lists = []
# i=1
# for url in urls:
#     for i in range(10):
#         try:
#             result = scrape_all(url)
#             lists.append(result)
#             data = pd.DataFrame(lists)
#             file_name = 'data_' + str(i) +'.csv'
#             data.to_csv('file_name')
#             i+=1
#             print("successfull url ",i)
#             break
#         except:
#             pass

# %%
hoankiem = scrape_all(urls[0])
# Out:
# Found page url:  15
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib64/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.12/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#            ^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_137307/2085271645.py", line 4, in scrape_house
#     source = get_source(url)
#              ^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_137307/785057415.py", line 12, in get_source
#     pageSource = driver.page_source
#                  ^^^^^^^^^^^^^^^^^^
#   File "/home/hnam/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 449, in page_source
#     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/hnam/.local/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py", line 348, in execute
#     self.error_handler.check_response(response)
#   File "/home/hnam/.local/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py", line 229, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# #0 0x564747060f83 <unknown>
# #1 0x564746d19b2b <unknown>
# #2 0x564746d5a3ba <unknown>
# #3 0x564746d92f94 <unknown>
# #4 0x564746d8b5bb <unknown>
# #5 0x564746d8ae0f <unknown>
# #6 0x564746ce22f8 <unknown>
# #7 0x564747025531 <unknown>
# #8 0x564747029455 <unknown>
# #9 0x564747011f55 <unknown>
# #10 0x56474702a0ef <unknown>
# #11 0x564746ff599f <unknown>
# #12 0x564746ce054f <unknown>
# #13 0x7f78c7e0b14a __libc_start_call_main
# #14 0x7f78c7e0b20b __libc_start_main_alias_2
# #15 0x564746caa9aa _start
#
# """
#
# The above exception was the direct cause of the following exception:
#
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 hoankiem = scrape_all(urls[0])
#
# Cell In[22], line 5, in scrape_all(url)
#       3 for n_pools in [8]:
#       4     with Pool(n_pools) as pool:
# ----> 5         result = list(pool.map(scrape_house, listing_urls))
#       7     pool.close()
#       8     pool.join()
#
# File /usr/lib64/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /usr/lib64/python3.12/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# InvalidSessionIdException: Message: invalid session id
# Stacktrace:
# #0 0x564747060f83 <unknown>
# #1 0x564746d19b2b <unknown>
# #2 0x564746d5a3ba <unknown>
# #3 0x564746d92f94 <unknown>
# #4 0x564746d8b5bb <unknown>
# #5 0x564746d8ae0f <unknown>
# #6 0x564746ce22f8 <unknown>
# #7 0x564747025531 <unknown>
# #8 0x564747029455 <unknown>
# #9 0x564747011f55 <unknown>
# #10 0x56474702a0ef <unknown>
# #11 0x564746ff599f <unknown>
# #12 0x564746ce054f <unknown>
# #13 0x7f78c7e0b14a __libc_start_call_main
# #14 0x7f78c7e0b20b __libc_start_main_alias_2
# #15 0x564746caa9aa _start

# %%
data = pd.DataFrame(lists)
data.to_csv('data.csv')

# %% [markdown]
# ## Preliminar Data Engineering for the data extracted by web crawler

# %% [markdown]
# ### Import libraries

# %%
import re
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('dataset.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1350 entries, 0 to 1349
# Data columns (total 37 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               1350 non-null   int64
#  1   url                                      1350 non-null   object
#  2   title                                    1291 non-null   object
#  3   bed                                      1234 non-null   object
#  4   title2                                   1020 non-null   object
#  5   location                                 1259 non-null   object
#  6   badge                                    186 non-null    object
#  7   cancellation_policy                      1252 non-null   object
#  8   accommodates                             1248 non-null   object
#  9   amenity_Hướng nhìn đẹp mắt               366 non-null    object
#  10  amenity_Phòng tắm                        973 non-null    object
#  11  amenity_Phòng ngủ và giặt ủi             1106 non-null   object
#  12  amenity_Giải trí                         1069 non-null   object
#  13  amenity_Gia đình                         420 non-null    object
#  14  amenity_Hệ thống sưởi và làm mát         1147 non-null   object
#  15  amenity_An toàn nhà ở                    913 non-null    object
#  16  amenity_Internet và văn phòng            1142 non-null   object
#  17  amenity_Đồ dùng nấu bếp và ăn uống       1125 non-null   object
#  18  amenity_Các đặc điểm về vị trí           524 non-null    object
#  19  amenity_Ngoài trời                       802 non-null    object
#  20  amenity_Chỗ đỗ xe và cơ sở vật chất      1086 non-null   object
#  21  amenity_Dịch vụ                          934 non-null    object
#  22  amenity_Không bao gồm                    1110 non-null   object
#  23  price_per_night                          1275 non-null   object
#  24  prices_Phí dịch vụ Airbnb                1137 non-null   object
#  25  rating_Total                             712 non-null    object
#  26  prices_Ưu đãi đặc biệt                   254 non-null    object
#  27  prices_Phí vệ sinh                       461 non-null    object
#  28  rating_Mức độ sạch sẽ                    397 non-null    object
#  29  rating_Độ chính xác                      397 non-null    object
#  30  rating_Nhận phòng                        397 non-null    object
#  31  rating_Giao tiếp                         397 non-null    object
#  32  rating_Vị trí                            397 non-null    object
#  33  rating_Giá trị                           397 non-null    object
#  34  prices_Giảm giá cho thời gian ở dài hạn  68 non-null     object
#  35  amenity_Quyền riêng tư và an toàn        223 non-null    object
#  36  prices_Giảm giá cho khách đặt sớm        6 non-null      object
# dtypes: int64(1), object(36)
# memory usage: 390.4+ KB

# %%
data.drop(data.columns[0], axis=1, inplace=True)
# data.fillna("", inplace = True)
# data.drop(columns = ['url'], inplace = True)

# %%
def make_rooms(data):
    # column 'bed' has format
    # 3 khách ·  · 1 phòng ngủ  ·  · 1 giường ·  · 1 phòng tắm
    data['rooms_split'] = data['bed'].str.split(' ·  · ')

    def extract_integer(x):
        if isinstance(x, list) and len(x) > 0:
            try:
                return int(x[0].split(' ')[0])
            except ValueError:
                return None
        return None

    data['cnt_guests'] = data['rooms_split'].apply(lambda x: extract_integer(x))
    data['cnt_bedrooms'] = data['rooms_split'].apply(lambda x: extract_integer(x[1:]) if isinstance(x, list) and len(x) > 1 else None)
    data['cnt_beds'] = data['rooms_split'].apply(lambda x: extract_integer(x[2:]) if isinstance(x, list) and len(x) > 2 else None)
    data['cnt_baths'] = data['rooms_split'].apply(lambda x: extract_integer(x[3:]) if isinstance(x, list) and len(x) > 3 else None)
    
    return data

# %%
def make_ratings_reviews(data):
    data['total_rating'] = data['rating_Total'].str.split(' · ').apply(lambda x: x[0].replace(',','.') if isinstance(x, list) and len(x) > 1 else None)
    data['total_reviews'] = data['rating_Total'].str.split(' · ').apply(lambda x: x[1].split(' ')[0] if isinstance(x, list) and len(x) > 1 else None)
    return data

# %%
def make_prices(data):
    data['price_per_night'] = data['price_per_night'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if re.search(r'\d+', str(x)) else None)
    data['prices_Phí dịch vụ Airbnb'] = data['prices_Phí dịch vụ Airbnb'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if re.search(r'\d+', str(x)) else 0)
    data['prices_Phí vệ sinh'] = data['prices_Phí vệ sinh'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if re.search(r'\d+', str(x)) else 0)
    data['prices_Ưu đãi đặc biệt'] = data['prices_Ưu đãi đặc biệt'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if re.search(r'\d+', str(x)) else 0)
    data['prices_Phí vệ sinh'] = data['prices_Phí vệ sinh'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if re.search(r'\d+', str(x)) else 0)
    data['prices_Giảm giá cho thời gian ở dài hạn'] = data['prices_Giảm giá cho thời gian ở dài hạn'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if re.search(r'\d+', str(x)) else 0)


    return data

# %%
def make_cancellation_policy(data):
    rules = ['miễn phí', 'một phần', 'không được']
    return_rules = ['free', 'part', 'no refund']
    
    def map_rules(text):
        if isinstance(text, str):
            for index, rule in enumerate(rules):
                if re.search(rule, text, flags=re.IGNORECASE):
                    return return_rules[index]
        return None
    
    data['cancellation_policy'] = data['cancellation_policy'].apply(map_rules)
    return data

# %%
def make_room_types(data):
    rules = ['phòng riêng', 'phòng', 'căn hộ']
    default_value = 'khác'
    data['title2'] = data['title2'].replace("",np.nan).fillna(data['title'])

    # Function to map room types based on title
    def map_room_type(text):
        if isinstance(text, str):
            for rule in rules:
                if rule == 'phòng riêng':
                    # Handling 'phòng riêng' case separately
                    match = re.search(r'\bphòng riêng\b', text, flags=re.IGNORECASE)
                    if match:
                        return 'phòng riêng'
                else:
                    match = re.search(rule, text, flags=re.IGNORECASE)
                    if match:
                        return rule
        return default_value

    data['room_type'] = data['title2'].apply(map_room_type)
    return data

# %%
def make_accommodates(data):
    data['accommodates'] = data['accommodates'].apply(lambda x: int(re.search(r'\d+', str(x)).group()) if re.search(r'\d+', str(x)) else None)
    data['accommodates'] = data['accommodates'].replace("",np.nan).fillna(data['cnt_guests'])
    return data

# %%
def make_clean(data):
  data = make_rooms(data)
  data = make_ratings_reviews(data)
  data = make_prices(data)
  data = make_cancellation_policy(data)
  data = make_room_types(data)
  data = make_accommodates(data)
  # data = make_location(data)
  return data

# %%
data = make_clean(data)

# %%
data.to_csv('data.csv')

# %%
data.head()
# Out:
#                                                  url  \
# 0  https://www.airbnb.com.vn/rooms/61849816949745...
# 1  https://www.airbnb.com.vn/rooms/10337900003460...
# 2  https://www.airbnb.com.vn/rooms/10302809627621...
# 3  https://www.airbnb.com.vn/rooms/86253981518653...
# 4  https://www.airbnb.com.vn/rooms/74105442785122...
#
#                                                title  \
# 0                          1 Phòng ngủ  có  2 giường
# 1  SkyView | Riverside | S1.01 TheRainbow VinhomesQ9
# 2    Home.byAB - Vinhomes Grand Park - Origami S7.03
# 3                        Căn hộ 1 phòng ngủ đáng yêu
# 4                             Căn hộ studio BNB HOME
#
#                                                  bed  \
# 0  4 khách ·  · 1 phòng ngủ  ·  · 2 giường ·  · 1...
# 1  3 khách ·  · 1 phòng ngủ  ·  · 2 giường ·  · 2...
# 2  2 khách ·  · 1 phòng ngủ  ·  · 1 giường ·  · 1...
# 3  2 khách ·  · 1 phòng ngủ  ·  · 2 giường ·  · 1...
# 4  2 khách ·  · 1 phòng ngủ  ·  · 1 giường ·  · 1...
#
#                                               title2  \
# 0       Toàn bộ căn hộ cho thuê tại Quận 9, Việt Nam
# 1  Toàn bộ căn hộ chung cư cao cấp tại Quận 9, Vi...
# 2       Toàn bộ căn hộ cho thuê tại Quận 9, Việt Nam
# 3                        Căn hộ 1 phòng ngủ đáng yêu
# 4  Toàn bộ căn hộ cho thuê tại Tp. Thủ Đức, Việt Nam
#
#                                        location                  badge  \
# 0       Quận 9, Thành phố Hồ Chí Minh, Việt Nam  Được khách\nyêu thích
# 1       Quận 9, Thành phố Hồ Chí Minh, Việt Nam                    NaN
# 2       Quận 9, Thành phố Hồ Chí Minh, Việt Nam                    NaN
# 3       Quận 9, Thành phố Hồ Chí Minh, Việt Nam                    NaN
# 4  Tp. Thủ Đức, Thành phố Hồ Chí Minh, Việt Nam                    NaN
#
#   cancellation_policy  accommodates  \
# 0                part           4.0
# 1                part           3.0
# 2                free           2.0
# 3                part           2.0
# 4                free           2.0
#
#                           amenity_Hướng nhìn đẹp mắt  \
# 0        ['Hướng nhìn ra đường chân trời thành phố']
# 1  ['Hướng nhìn ra kênh', 'Hướng nhìn ra đường ch...
# 2                           ['Hướng nhìn ra hồ bơi']
# 3  ['Hướng nhìn ra công viên', 'Hướng nhìn ra sông']
# 4  ['Hướng nhìn ra sông', 'Hướng nhìn ra hồ', 'Hư...
#
#                                    amenity_Phòng tắm  ...  \
# 0  ['Máy sấy tóc', 'Sản phẩm vệ sinh', 'Dầu gội đ...  ...
# 1  ['Máy sấy tóc', 'Sản phẩm vệ sinh', 'Dầu gội đ...  ...
# 2        ['Máy sấy tóc', 'Dầu gội đầu', 'Nước nóng']  ...
# 3  ['Máy sấy tóc', 'Sản phẩm vệ sinh', 'Dầu gội đ...  ...
# 4  ['Máy sấy tóc', 'Sản phẩm vệ sinh', 'Dầu gội đ...  ...
#
#   amenity_Quyền riêng tư và an toàn prices_Giảm giá cho khách đặt sớm  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#                                          rooms_split cnt_guests cnt_bedrooms  \
# 0  [4 khách, 1 phòng ngủ , 2 giường, 1 phòng tắm ...        4.0          1.0
# 1     [3 khách, 1 phòng ngủ , 2 giường, 2 phòng tắm]        3.0          1.0
# 2     [2 khách, 1 phòng ngủ , 1 giường, 1 phòng tắm]        2.0          1.0
# 3     [2 khách, 1 phòng ngủ , 2 giường, 1 phòng tắm]        2.0          1.0
# 4     [2 khách, 1 phòng ngủ , 1 giường, 1 phòng tắm]        2.0          1.0
#
#   cnt_beds cnt_baths total_rating total_reviews room_type
# 0      2.0       1.0         None          None    căn hộ
# 1      2.0       2.0         None          None    căn hộ
# 2      1.0       1.0          5.0             4    căn hộ
# 3      2.0       1.0         4.86             7     phòng
# 4      1.0       1.0         4.83            12    căn hộ
#
# [5 rows x 44 columns]
